# %%
import gym
from solo import *
from policies import Greedy, EGreedy
from interact import Interact
import matplotlib.pyplot as plt
import numpy as np

# %%
env = gym.make('CartPole-v0')
n_actions = env.action_space.n
n_features = env.observation_space.shape[0]

# %%
env.observation_space
# Out:
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
agent = TreeAgent(n_actions, n_features, 0.6, EGreedy(0.1), EGreedy(0.1), 1, 0.1)
eps_act, eps_obs, eps_rewards, eps_states, eps_actions = Interact.train(env, agent, 2000)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2000.0), HTML(value='')))

# %%
eps_reward = [sum(ep_rewards) for ep_rewards in eps_rewards]
plt.plot(eps_reward)
plt.show()

# %%
Interact.test(env, agent, 0.00)
# Out:
# 27
